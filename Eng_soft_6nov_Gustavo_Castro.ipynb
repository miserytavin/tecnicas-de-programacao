# %% [markdown]
# <a href="https://colab.research.google.com/github/miserytavin/tecnicas-de-programacao/blob/main/Eng_soft_6nov_Gustavo_Castro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2**3
# Out:
# 8

# %%
23/7
# Out:
# 3.2857142857142856

# %%
23%7
# Out:
# 2

# %%
5 + 5 * 5 / 5
# Out:
# 10.0

# %%
4 ** (4 / 2) + 7
# Out:
# 23.0

# %%
#1
a = float(input ("Informe o primeiro número: "))
b = float(input ("Informe o segundo número: "))
print(float(a+b))
# Out:
# Informe o primeiro número: 5
# Informe o segundo número: 4
# 9.0

# %%
#2
a=float(input("Nota da P1: "))
b=float(input("Nota da p2: "))
print("A média das notas é: ", (a+b)/2)
# Out:
# Nota da P1: 123
# Nota da p2: 54
# A média das notas é:  88.5

# %%
#3
nome_usuario = input("Insira seu nome: ")
print("Olá ", nome_usuario)
# Out:
# Insira seu nomeGustavo
# Olá  Gustavo

# %%
#4
nome_usuario = input("Insira seu nome: ")
ano_nasc = input("Insira o ano em que você nasceu: ")
print(nome_usuario, "nasceu no ano de ",ano_nasc)
# Out:
# Insira seu nome: Gustavo
# Insira o ano em que você nasceu: 2006
# Gustavo nasceu no ano de  2006

# %%
nome_usuario = input("Insira seu nome: ")
idade = input("Insira sua idade: ")
print("Olá", nome_usuario, "você nasceu no ano de ? ", (2025 - int(idade)))
print(nome_usuario," tem ", int(idade))
